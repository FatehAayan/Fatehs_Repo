# %% [markdown]
# # Fateh Aayan 20i-0627

# %% [markdown]
# # Part 1

# %%
class university:
    campus=5
    def __init__(self,name,address):
        self.name=name
        self.address=address
    def _display(self):
        print(f"{self.name} university is located in {self.address}")

# %%
class department(university):
    def __init__(self,pname,program,u_name,u_address):
        super().__init__(u_name,u_address)
        self.pname=pname
        self.program=program
    def display(self):
        self._display()
        print(f"Name of Department : {self.pname} | Program : {self.program}")

# %%
U_Fast=university("FAST", "Islamabad")
U_Fast._display()
# Out:
# FAST university is located in Islamabad

# %%
obj2=department("CS","Ai","FAST","Lahore")
obj2.display()
# Out:
# FAST university is located in Lahore
# Name of Department : CS | Program : Ai

# %%
list1=["Aamish","Fateh","Aliyan","Maaz","Sherry"]
for index,name in enumerate(list1):
    print(index, name)
# Out:
# 0 Aamish
# 1 Fateh
# 2 Aliyan
# 3 Maaz
# 4 Sherry

# %% [markdown]
# # Part 2

# %%
list2=["racecar","abcd","roar","bird","amanda","nissan","sunset","xeno"]
count=0
for i in list2:
    if len(i)>2 and i[0]==i[-1]:
        count+=1
        print(i)
print(f"count={count}")
# Out:
# racecar
# roar
# amanda
# nissan
# count=4

# %%
list3=sorted(list2)
list3
# Out:
# ['abcd', 'amanda', 'bird', 'nissan', 'racecar', 'roar', 'sunset', 'xeno']

# %%
toup=("racecar","abcd","roar","bird","amanda","nissan","sunset","xeno")
sorted_t=sorted(toup,key=lambda l:l[-1])

sorted_t
# Out:
# ['amanda', 'abcd', 'bird', 'nissan', 'xeno', 'racecar', 'roar', 'sunset']

# %%
import pandas as pd

# %%
list4=[1,2,2,2,3,3,6,6,6,6,9,9,0,0]
list4=pd.unique(list4)
list4
# Out:
# array([1, 2, 3, 6, 9, 0])

# %%
list5=[4,5,6,7]
list6=[1,2,3]
merge=[*list6,*list5]

print(sorted(merge))
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# # DataFrame

# %%
df=pd.read_csv("C:\\Users\\sadia\\Downloads\\Semester V\\ML Lab\\drinks.csv")

# %%
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
print(f"Number of Ros = {len(df)}")
# Out:
# Number of Ros = 193

# %%
df=df.dropna()

# %%
print(f"Number of Ros = {len(df)}")
# Out:
# Number of Ros = 170

# %%
def col(column):
    print(df[column])
col("continent")
# Out:
# 0      AS
# 1      EU
# 2      AF
# 3      EU
# 4      AF
#        ..
# 188    SA
# 189    AS
# 190    AS
# 191    AF
# 192    AF
# Name: continent, Length: 170, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
df["wine_servings"].plot(kind='hist',color='purple',edgecolor='white', linewidth=1.6)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.scatter(df["total_litres_of_pure_alcohol"],df["continent"])

# %%
Label=df['continent'].unique()
df2=df.groupby('continent').sum()
x=np.array(df2['wine_servings'])
plt.pie(x,labels=Label)
plt.title("ratio of wine servings of the continents")
plt.show()

# %%
plt.bar(Label,df2['wine_servings'],color='purple',edgecolor='white', linewidth=1.6)
plt.show()

# %%
size=(5,5)
F=plt.figure(figsize=(size))
plot=F.add_subplot(projection='3d')
plot.scatter(df['wine_servings'],df['total_litres_of_pure_alcohol'],df['beer_servings'])
plot.w_xaxis.set_pane_color((0.6,0.2,0.9,0.6))
plot.w_yaxis.set_pane_color((0.5,0.2,0.5,0.5))
plot.w_zaxis.set_pane_color((0.2,0.1,0.5,0.5))
plot.set_xlabel('Wine')
plot.set_ylabel('pure alcohol')
plot.set_zlabel('beer')
# Out:
# Text(0.5, 0, 'beer')
